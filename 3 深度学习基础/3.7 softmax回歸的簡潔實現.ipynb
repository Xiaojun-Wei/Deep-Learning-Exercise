# %%
import tensorflow as tf
from tensorflow import keras

# %% [markdown]
# ## 3.7.1 獲取和讀取數據 ##

# %%
fashion_mnist = keras.datasets.fashion_mnist
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()

# %%
# 對數據進行歸一化處理
x_train = x_train/255.0
x_test = x_test/255.0

# %% [markdown]
# ## 3.7.2 定義和初始化模型 ##

# %%
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(10, activation=tf.nn.softmax)
])
# Out:
# 2022-04-08 14:11:35.149532: I tensorflow/core/platform/cpu_feature_guard.cc:145] This TensorFlow binary is optimized with Intel(R) MKL-DNN to use the following CPU instructions in performance critical operations:  SSE4.1 SSE4.2
# To enable them in non-MKL-DNN operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-04-08 14:11:35.157072: I tensorflow/core/common_runtime/process_util.cc:115] Creating new thread pool with default inter op setting: 8. Tune using inter_op_parallelism_threads for best performance.

# %%
## 3.7.3 softmax和交叉熵損失函數 ##

# %%
loss = 'sparse_categorical_crossentropy'

# %% [markdown]
# ## 3.7.4 定義優化函數 ##

# %%
optimizer = tf.keras.optimizers.SGD(0.1)

# %% [markdown]
# ## 3.7.5 訓練模型 ##

# %% [markdown]
# model.compile(optimizer=tf.keras.optimizers.SGD(0.1),
#               loss = 'sparse_categorical_crossentropy',
#               metrics=['accuracy'])
#
# model.fit(x_train, y_train, epochs=5, batch_size=256)

# %% [markdown]
# ## 比較模型在測試數據集上的表現情況 ##

# %%
test_loss, test_acc = model.evaluate(x_test, y_test)
print("Test Acc:", test_acc)
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# Test Acc: 0.8206
